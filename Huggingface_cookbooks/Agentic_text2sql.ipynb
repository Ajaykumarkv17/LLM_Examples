# %% [markdown]
# **In this tutorial, we’ll see how to implement an agent that leverages SQL using transformers.agents.**
#
# What’s the advantage over a standard text-to-SQL pipeline?
#
# A standard text-to-sq pipeline is brittle, since the generated SQL query can be incorrect. Even worse, the query could be incorrect, but not raise an error, instead giving some incorrect/useless outputs without raising an alarm.
#
# 👉 Instead, an agent system is able to critically inspect outputs and decide if the query needs to be changed or not, thus giving it a huge performance boost.

# %%
# !pip install transformers["agents"]
# Out:
# Requirement already satisfied: transformers[agents] in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (4.46.0)
# Requirement already satisfied: filelock in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (0.26.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (2024.9.11)
# Requirement already satisfied: requests in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (4.66.5)
# Requirement already satisfied: Pillow<=15.0,>=10.0.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (11.0.0)
# Requirement already satisfied: accelerate>=0.26.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (1.2.1)
# Requirement already satisfied: datasets!=2.5.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (2.14.5)
# Collecting diffusers (from transformers[agents])
#   Downloading diffusers-0.31.0-py3-none-any.whl.metadata (18 kB)
# Collecting opencv-python (from transformers[agents])
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[agents])
#   Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: torch in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers[agents]) (2.5.0)
# Requirement already satisfied: psutil in c:\users\ajaykumarkv\appdata\roaming\python\python312\site-packages (from accelerate>=0.26.0->transformers[agents]) (6.1.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from datasets!=2.5.0->transformers[agents]) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from datasets!=2.5.0->transformers[agents]) (0.3.7)
# Requirement already satisfied: pandas in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from datasets!=2.5.0->transformers[agents]) (2.2.3)
# Requirement already satisfied: xxhash in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from datasets!=2.5.0->transformers[agents]) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from datasets!=2.5.0->transformers[agents]) (0.70.15)
# Requirement already satisfied: fsspec<2023.9.0,>=2023.1.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<2023.9.0,>=2023.1.0->datasets!=2.5.0->transformers[agents]) (2023.6.0)
# Requirement already satisfied: aiohttp in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from datasets!=2.5.0->transformers[agents]) (3.9.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers[agents]) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers[agents]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers[agents]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers[agents]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers[agents]) (2024.8.30)
# Requirement already satisfied: networkx in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from torch->transformers[agents]) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from torch->transformers[agents]) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from torch->transformers[agents]) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from torch->transformers[agents]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch->transformers[agents]) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers[agents]) (0.4.6)
# Requirement already satisfied: importlib-metadata in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from diffusers->transformers[agents]) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets!=2.5.0->transformers[agents]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets!=2.5.0->transformers[agents]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets!=2.5.0->transformers[agents]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets!=2.5.0->transformers[agents]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets!=2.5.0->transformers[agents]) (1.18.3)
# Requirement already satisfied: zipp>=3.20 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata->diffusers->transformers[agents]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->transformers[agents]) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajaykumarkv\appdata\roaming\python\python312\site-packages (from pandas->datasets!=2.5.0->transformers[agents]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets!=2.5.0->transformers[agents]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets!=2.5.0->transformers[agents]) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets!=2.5.0->transformers[agents]) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->datasets!=2.5.0->transformers[agents]) (0.2.1)
# Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/992.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/992.0 kB ? eta -:--:--
#    ---------------------------------------- 992.0/992.0 kB 3.9 MB/s eta 0:00:00
# Downloading diffusers-0.31.0-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.8/2.9 MB 3.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.6/2.9 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 3.7 MB/s eta 0:00:00
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.8 MB 3.7 MB/s eta 0:00:11
#    - -------------------------------------- 1.3/38.8 MB 3.7 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/38.8 MB 3.8 MB/s eta 0:00:10
#    --- ------------------------------------ 3.1/38.8 MB 3.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 3.9/38.8 MB 3.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.7/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/38.8 MB 3.8 MB/s eta 0:00:09
#    ------ --------------------------------- 6.3/38.8 MB 3.7 MB/s eta 0:00:09
#    ------- -------------------------------- 7.1/38.8 MB 3.8 MB/s eta 0:00:09
#    -------- ------------------------------- 7.9/38.8 MB 3.8 MB/s eta 0:00:09
#    --------- ------------------------------ 8.9/38.8 MB 3.8 MB/s eta 0:00:08
#    --------- ------------------------------ 9.7/38.8 MB 3.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.5/38.8 MB 3.8 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.3/38.8 MB 3.8 MB/s eta 0:00:08
#    ------------ --------------------------- 12.1/38.8 MB 3.8 MB/s eta 0:00:08
#    ------------- -------------------------- 12.8/38.8 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 13.6/38.8 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 14.4/38.8 MB 3.7 MB/s eta 0:00:07
#    --------------- ------------------------ 15.2/38.8 MB 3.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.0/38.8 MB 3.7 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.8/38.8 MB 3.7 MB/s eta 0:00:06
#    ------------------ --------------------- 17.6/38.8 MB 3.7 MB/s eta 0:00:06
#    ------------------ --------------------- 18.1/38.8 MB 3.7 MB/s eta 0:00:06
#    ------------------- -------------------- 19.1/38.8 MB 3.7 MB/s eta 0:00:06
#    -------------------- ------------------- 19.9/38.8 MB 3.7 MB/s eta 0:00:06
#    --------------------- ------------------ 20.4/38.8 MB 3.7 MB/s eta 0:00:05
#    --------------------- ------------------ 21.2/38.8 MB 3.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.8 MB 3.7 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.8/38.8 MB 3.7 MB/s eta 0:00:05
#    ------------------------ --------------- 23.6/38.8 MB 3.7 MB/s eta 0:00:05
#    ------------------------- -------------- 24.4/38.8 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.4/38.8 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 26.0/38.8 MB 3.7 MB/s eta 0:00:04
#    --------------------------- ------------ 27.0/38.8 MB 3.7 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.8/38.8 MB 3.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.6/38.8 MB 3.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 29.1/38.8 MB 3.7 MB/s eta 0:00:03
#    ------------------------------ --------- 29.9/38.8 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 30.7/38.8 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/38.8 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 32.5/38.8 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.3/38.8 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.1/38.8 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.9/38.8 MB 3.7 MB/s eta 0:00:02
#    ------------------------------------ --- 35.7/38.8 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.8 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, opencv-python, diffusers
# Successfully installed diffusers-0.31.0 opencv-python-4.10.0.84 sentencepiece-0.2.0
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import (
    create_engine,
    MetaData,
    Table,
    Column,
    String,
    Integer,
    Float,
    insert,
    inspect,
    text,
)

engine = create_engine("sqlite:///:memory:")
metadata_obj = MetaData()

# create city SQL table
table_name = "receipts"
receipts = Table(
    table_name,
    metadata_obj,
    Column("receipt_id", Integer, primary_key=True),
    Column("customer_name", String(16), primary_key=True),
    Column("price", Float),
    Column("tip", Float),
)
metadata_obj.create_all(engine)

# %%
metadata_obj.tables
# Out:
# FacadeDict({'receipts': Table('receipts', MetaData(), Column('receipt_id', Integer(), table=<receipts>, primary_key=True, nullable=False), Column('customer_name', String(length=16), table=<receipts>, primary_key=True, nullable=False), Column('price', Float(), table=<receipts>), Column('tip', Float(), table=<receipts>), schema=None)})

# %%
rows = [
    {"receipt_id": 1, "customer_name": "Alan Payne", "price": 12.06, "tip": 1.20},
    {"receipt_id": 2, "customer_name": "Alex Mason", "price": 23.86, "tip": 0.24},
    {"receipt_id": 3, "customer_name": "Woodrow Wilson", "price": 53.43, "tip": 5.43},
    {"receipt_id": 4, "customer_name": "Margaret James", "price": 21.11, "tip": 1.00},
]
for row in rows:
    stmt = insert(receipts).values(**row)
    with engine.begin() as connection:
        cursor = connection.execute(stmt)

# %%
with engine.connect() as con:
    rows = con.execute(text("""SELECT * from receipts"""))
    for row in rows:
        print(row)
# Out:
# (1, 'Alan Payne', 12.06, 1.2)
# (2, 'Alex Mason', 23.86, 0.24)
# (3, 'Woodrow Wilson', 53.43, 5.43)
# (4, 'Margaret James', 21.11, 1.0)

# %%
inspector = inspect(engine)
columns_info = [(col["name"], col["type"]) for col in inspector.get_columns("receipts")]

table_description = "Columns:\n" + "\n".join([f"  - {name}: {col_type}" for name, col_type in columns_info])
print(table_description)
# Out:
# Columns:
#   - receipt_id: INTEGER
#   - customer_name: VARCHAR(16)
#   - price: FLOAT
#   - tip: FLOAT

# %%
from transformers.agents import tool


@tool
def sql_engin(query: str) -> str:
    """
    Allows you to perform SQL queries on the table. Returns a string representation of the result.
    The table is named 'receipts'. Its description is as follows:
        Columns:
        - receipt_id: INTEGER
        - customer_name: VARCHAR(16)
        - price: FLOAT
        - tip: FLOAT

    Args:
        query: The query to perform. This should be correct SQL.
    """
    output = ""
    with engine.connect() as con:
        rows = con.execute(text(query))
        for row in rows:
            output += "\n" + str(row)
    return output

# %%
from transformers.agents import ReactCodeAgent, HfApiEngine

agent = ReactCodeAgent(
    tools=[sql_engin],
    llm_engine=HfApiEngine("meta-llama/Meta-Llama-3-8B-Instruct"),
)

# %%
agent.run("Can you give me the name of the client who got the most expensive receipt?")
# Out:
# ======== New task ========
# Can you give me the name of the client who got the most expensive receipt?
# Error in code parsing:
# The code blob you used is invalid: due to the following error: 'NoneType' object has no attribute 'group'
# This means that the regex pattern ```(?:py|python)?\n(.*?)\n``` was not respected: make sure to include code with the correct pattern, for instance:
# Thoughts: Your thoughts
# Code:
# ```py
# # Your python code here
# ```<end_action>. Make sure to provide correct code
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 121, in parse_code_blob
#     return match.group(1).strip()
#            ^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1118, in step
#     code_action = parse_code_blob(raw_code_action)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 123, in parse_code_blob
#     raise ValueError(
# ValueError:
# The code blob you used is invalid: due to the following error: 'NoneType' object has no attribute 'group'
# This means that the regex pattern ```(?:py|python)?\n(.*?)\n``` was not respected: make sure to include code with the correct pattern, for instance:
# Thoughts: Your thoughts
# Code:
# ```py
# # Your python code here
# ```<end_action>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 811, in direct_run
#     step_logs = self.step()
#                 ^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1121, in step
#     raise AgentParsingError(error_msg)
# transformers.agents.agents.AgentParsingError: Error in code parsing:
# The code blob you used is invalid: due to the following error: 'NoneType' object has no attribute 'group'
# This means that the regex pattern ```(?:py|python)?\n(.*?)\n``` was not respected: make sure to include code with the correct pattern, for instance:
# Thoughts: Your thoughts
# Code:
# ```py
# # Your python code here
# ```<end_action>. Make sure to provide correct code
# === Agent thoughts:
# I apologize for the mistake. Let me try again.
#
# Thought: I will try to query the receipts table using the sql_engine tool to get the customer name and price of the most expensive receipt. I will print the result to get the necessary information.
# >>> Agent is executing the code below:
# result = sql_engine(query="SELECT customer_name, price FROM receipts ORDER BY price DESC LIMIT 1;")
# print(result)
# ====
# Print outputs:
#
# ('Woodrow Wilson', 53.43)
#
# === Agent thoughts:
# Thought: Now that I have the name and price of the most expensive receipt, I'll use the `print` statement to output the result again and then use the `final_answer` tool to provide the final answer.
# >>> Agent is executing the code below:
# print('Woodrow Wilson', 53.43)
# final_answer('Woodrow Wilson')
# ====
# Print outputs:
# Woodrow Wilson 53.43
#
# Last output from code snippet:
# Woodrow Wilson
# Final answer:
# Woodrow Wilson
# 'Woodrow Wilson'

# %%
table_name = "waiters"
receipts = Table(
    table_name,
    metadata_obj,
    Column("receipt_id", Integer, primary_key=True),
    Column("waiter_name", String(16), primary_key=True),
)
metadata_obj.create_all(engine)

rows = [
    {"receipt_id": 1, "waiter_name": "Corey Johnson"},
    {"receipt_id": 2, "waiter_name": "Michael Watts"},
    {"receipt_id": 3, "waiter_name": "Michael Watts"},
    {"receipt_id": 4, "waiter_name": "Margaret James"},
]
for row in rows:
    stmt = insert(receipts).values(**row)
    with engine.begin() as connection:
        cursor = connection.execute(stmt)

# %%
updated_description = """Allows you to perform SQL queries on the table. Beware that this tool's output is a string representation of the execution output.
It can use the following tables:"""

inspector = inspect(engine)
for table in ["receipts", "waiters"]:
    columns_info = [(col["name"], col["type"]) for col in inspector.get_columns(table)]

    table_description = f"Table '{table}':\n"

    table_description += "Columns:\n" + "\n".join([f"  - {name}: {col_type}" for name, col_type in columns_info])
    updated_description += "\n\n" + table_description

print(updated_description)
# Out:
# Allows you to perform SQL queries on the table. Beware that this tool's output is a string representation of the execution output.
# It can use the following tables:
#
# Table 'receipts':
# Columns:
#   - receipt_id: INTEGER
#   - customer_name: VARCHAR(16)
#   - price: FLOAT
#   - tip: FLOAT
#
# Table 'waiters':
# Columns:
#   - receipt_id: INTEGER
#   - waiter_name: VARCHAR(16)

# %%
sql_engin.description=updated_description

agent = ReactCodeAgent(
    tools=[sql_engin],
    llm_engine=HfApiEngine("Qwen/Qwen2.5-72B-Instruct"),
)

agent.run("Which waiter got more total money from tips?")
# Out:
# ======== New task ========
# Which waiter got more total money from tips?
# === Agent thoughts:
# Thought: To determine which waiter got more total money from tips, I will perform a SQL query that will sum the tips for each waiter and return their names along with the total sum of their tips. The query will be executed on the 'receipts' and 'waiters' tables by joining them on the 'receipt_id' field.
# >>> Agent is executing the code below:
# query = """
# SELECT w.waiter_name, SUM(r.tip) AS total_tips
# FROM receipts r
# JOIN waiters w ON r.receipt_id = w.receipt_id
# GROUP BY w.waiter_name
# ORDER BY total_tips DESC
# """
#
# results = sql_engin(query=query)
# print(results)
# ====
# Print outputs:
#
# ('Michael Watts', 5.67)
# ('Corey Johnson', 1.2)
# ('Margaret James', 1.0)
#
# === Agent thoughts:
# Thought: The SQL query has successfully provided the total tips for each waiter, with 'Michael Watts' having the highest total. I will now determine the waiter with the most total tips and provide a final answer.
# >>> Agent is executing the code below:
# # Split the results into a list of tuples
# results_list = [tuple(item) for item in results.strip('()').split('), (')]
#
# # Find the waiter with the most total tips
# most_tips_waiter = max(results_list, key=lambda x: float(x[1]))
#
# # Provide the final answer
# final_answer(most_tips_waiter)
# ====
# Code execution failed due to the following error:
# could not convert string to float: '('
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1135, in step
#     result = self.python_evaluator(
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 895, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 439, in evaluate_call
#     output = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 109, in lambda_func
#     return evaluate_ast(lambda_expression.body, new_state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 439, in evaluate_call
#     output = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: '('
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 811, in direct_run
#     step_logs = self.step()
#                 ^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1155, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# could not convert string to float: '('
# === Agent thoughts:
# Thought: The previous attempt to parse the results failed because the output was not properly formatted as a list of tuples. I will manually parse the string to extract the waiter name and total tips, then convert the strings to floats where necessary to determine the waiter with the highest total tips.
# >>> Agent is executing the code below:
# # Manually split the results into a list of tuples
# results_list = [item.strip("()").split(", ") for item in results.split("\n")]
#
# # Convert the tip values to floats and create a list of tuples (waiter_name, total_tips)
# results_list = [(name, float(tips)) for name, tips in results_list]
#
# # Find the waiter with the most total tips
# most_tips_waiter = max(results_list, key=lambda x: x[1])
#
# # Provide the final answer
# final_answer(most_tips_waiter)
# ====
# Code execution failed due to the following error:
# list index out of range
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1135, in step
#     result = self.python_evaluator(
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 895, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 753, in evaluate_ast
#     return evaluate_listcomp(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 583, in evaluate_listcomp
#     return inner_evaluate(listcomp.generators, 0, state)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 576, in inner_evaluate
#     new_state[elem.id] = value[idx]
#                          ~~~~~^^^^^
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 811, in direct_run
#     step_logs = self.step()
#                 ^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1155, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# list index out of range
# === Agent thoughts:
# Thought: There seems to be an issue with the way the results are being processed. To be more robust, I'll first clean up the results string by removing any unwanted characters and then convert the string representation of the results into a list of tuples. This will allow us to correctly identify the waiter with the highest total tips.
# >>> Agent is executing the code below:
# # Clean up the results string
# results = results.replace('(', '').replace(')', '').replace('\'', '')
#
# # Convert the cleaned string to a list of tuples
# results_list = [tuple(item.split(', ')) for item in results.split('\n')]
#
# # Convert the tip values to floats and create a list of tuples (waiter_name, total_tips)
# results_list = [(name, float(tips)) for name, tips in results_list]
#
# # Find the waiter with the most total tips
# most_tips_waiter = max(results_list, key=lambda x: x[1])
#
# # Provide the final answer
# final_answer(most_tips_waiter)
# ====
# Code execution failed due to the following error:
# tuple index out of range
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1135, in step
#     result = self.python_evaluator(
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 895, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 753, in evaluate_ast
#     return evaluate_listcomp(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 583, in evaluate_listcomp
#     return inner_evaluate(listcomp.generators, 0, state)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 576, in inner_evaluate
#     new_state[elem.id] = value[idx]
#                          ~~~~~^^^^^
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 811, in direct_run
#     step_logs = self.step()
#                 ^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1155, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# tuple index out of range
# === Agent thoughts:
# Thought: It seems there is an issue with the format of the `results` string. The error suggests that the string might not be in the expected format, causing the split operation to produce unexpected results. I will print the raw `results` string to understand its exact format and then adjust the parsing logic accordingly.
# >>> Agent is executing the code below:
# # Print the raw results string to understand its format
# print(results)
# ====
# Print outputs:
#
# Michael Watts, 5.67
# Corey Johnson, 1.2
# Margaret James, 1.0
#
# === Agent thoughts:
# Thought: The raw results string is a simple list of lines, where each line contains the waiter's name and the total tips separated by a comma. I can split the string by newline characters to get each line and then split each line by the comma to get the name and tips. This will allow me to correctly parse the data and determine the waiter with the highest total tips.
# >>> Agent is executing the code below:
# # Split the results string by newline to get each line
# lines = results.split('\n')
#
# # Convert each line into a tuple (waiter_name, total_tips)
# results_list = [(line.split(", ")[0].strip(), float(line.split(", ")[1].strip())) for line in lines]
#
# # Find the waiter with the most total tips
# most_tips_waiter = max(results_list, key=lambda x: x[1])
#
# # Provide the final answer
# final_answer(most_tips_waiter)
# ====
# Code execution failed due to the following error:
# EXECUTION FAILED:
# Evaluation stopped at line 'results_list = [(line.split(", ")[0].strip(), float(line.split(", ")[1].strip())) for line in lines]' because of the following error:
# Index 1 out of bounds for list of length 1
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 895, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 753, in evaluate_ast
#     return evaluate_listcomp(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 583, in evaluate_listcomp
#     return inner_evaluate(listcomp.generators, 0, state)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 580, in inner_evaluate
#     result.extend(inner_evaluate(generators, index + 1, new_state))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 568, in inner_evaluate
#     return [evaluate_ast(listcomp.elt, current_state, static_tools, custom_tools)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 751, in evaluate_ast
#     return tuple(evaluate_ast(elt, state, static_tools, custom_tools) for elt in expression.elts)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 751, in <genexpr>
#     return tuple(evaluate_ast(elt, state, static_tools, custom_tools) for elt in expression.elts)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 394, in evaluate_call
#     args.append(evaluate_ast(arg, state, static_tools, custom_tools))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 368, in evaluate_call
#     obj = evaluate_ast(call.func.value, state, static_tools, custom_tools)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 804, in evaluate_ast
#     return evaluate_subscript(expression, state, static_tools, custom_tools)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 460, in evaluate_subscript
#     raise InterpreterError(f"Index {index} out of bounds for list of length {len(value)}")
# transformers.agents.python_interpreter.InterpreterError: Index 1 out of bounds for list of length 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1135, in step
#     result = self.python_evaluator(
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/python_interpreter.py", line 904, in evaluate_python_code
#     raise InterpreterError(msg)
# transformers.agents.python_interpreter.InterpreterError: EXECUTION FAILED:
# Evaluation stopped at line 'results_list = [(line.split(", ")[0].strip(), float(line.split(", ")[1].strip())) for line in lines]' because of the following error:
# Index 1 out of bounds for list of length 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 811, in direct_run
#     step_logs = self.step()
#                 ^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/transformers/agents/agents.py", line 1155, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# EXECUTION FAILED:
# Evaluation stopped at line 'results_list = [(line.split(", ")[0].strip(), float(line.split(", ")[1].strip())) for line in lines]' because of the following error:
# Index 1 out of bounds for list of length 1
# Reached max iterations.
# NoneType: None
# 'Based on the results provided, the waiter who got the most total money from tips is **Michael Watts** with a total of **5.67**.'

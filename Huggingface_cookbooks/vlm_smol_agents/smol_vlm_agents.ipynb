# %%
pip install "smolagents[all]" helium selenium python-dotenv
# Out:
# Collecting helium
#   Downloading helium-5.1.0.tar.gz (30 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting selenium
#   Downloading selenium-4.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dotenv in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: smolagents[all] in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: torch in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (2.5.1)
# Requirement already satisfied: torchaudio in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (2.5.1)
# Requirement already satisfied: torchvision in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (0.20.1)
# Requirement already satisfied: transformers>=4.0.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (4.47.1)
# Requirement already satisfied: requests>=2.32.3 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (2.32.3)
# Requirement already satisfied: rich>=13.9.4 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (13.9.4)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (2.2.3)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (3.1.5)
# Requirement already satisfied: pillow>=11.0.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (11.0.0)
# Requirement already satisfied: markdownify>=0.14.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (0.14.1)
# Requirement already satisfied: gradio>=5.8.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (5.9.1)
# Requirement already satisfied: duckduckgo-search>=6.3.7 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (7.2.0)
# Requirement already satisfied: e2b-code-interpreter>=1.0.3 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (1.0.3)
# Requirement already satisfied: litellm>=1.55.10 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from smolagents[all]) (1.57.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.28.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from selenium) (4.12.2)
# Collecting websocket-client~=1.8 (from selenium)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: click>=8.1.7 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from duckduckgo-search>=6.3.7->smolagents[all]) (8.1.7)
# Requirement already satisfied: primp>=0.9.3 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from duckduckgo-search>=6.3.7->smolagents[all]) (0.9.3)
# Requirement already satisfied: lxml>=5.3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from duckduckgo-search>=6.3.7->smolagents[all]) (5.3.0)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from e2b-code-interpreter>=1.0.3->smolagents[all]) (24.2.0)
# Requirement already satisfied: e2b<2.0.0,>=1.0.4 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from e2b-code-interpreter>=1.0.3->smolagents[all]) (1.0.5)
# Requirement already satisfied: httpx<1.0.0,>=0.20.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from e2b-code-interpreter>=1.0.3->smolagents[all]) (0.27.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (4.7.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.115.6)
# Requirement already satisfied: ffmpy in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.5.0)
# Requirement already satisfied: gradio-client==1.5.2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (1.5.2)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.27.0)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (3.10.12)
# Requirement already satisfied: packaging in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (24.1)
# Requirement already satisfied: pydantic>=2.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (2.8.2)
# Requirement already satisfied: pydub in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.0.18)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.8.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.15.1)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio>=5.8.0->smolagents[all]) (0.34.0)
# Requirement already satisfied: fsspec in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio-client==1.5.2->gradio>=5.8.0->smolagents[all]) (2023.6.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from gradio-client==1.5.2->gradio>=5.8.0->smolagents[all]) (14.1)
# Requirement already satisfied: aiohttp in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from litellm>=1.55.10->smolagents[all]) (3.9.5)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from litellm>=1.55.10->smolagents[all]) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from litellm>=1.55.10->smolagents[all]) (4.23.0)
# Requirement already satisfied: openai>=1.55.3 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from litellm>=1.55.10->smolagents[all]) (1.59.3)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from litellm>=1.55.10->smolagents[all]) (0.8.0)
# Requirement already satisfied: tokenizers in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from litellm>=1.55.10->smolagents[all]) (0.21.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from markdownify>=0.14.1->smolagents[all]) (4.12.3)
# Requirement already satisfied: six<2,>=1.15 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from markdownify>=0.14.1->smolagents[all]) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajaykumarkv\appdata\roaming\python\python312\site-packages (from pandas>=2.2.3->smolagents[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.2.3->smolagents[all]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.2.3->smolagents[all]) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.3->smolagents[all]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.3->smolagents[all]) (3.10)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from rich>=13.9.4->smolagents[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ajaykumarkv\appdata\roaming\python\python312\site-packages (from rich>=13.9.4->smolagents[all]) (2.18.0)
# Requirement already satisfied: filelock in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.0.0->smolagents[all]) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.0.0->smolagents[all]) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.0.0->smolagents[all]) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.0.0->smolagents[all]) (4.66.5)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: networkx in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from torch->smolagents[all]) (3.4.2)
# Requirement already satisfied: setuptools in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from torch->smolagents[all]) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from torch->smolagents[all]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch->smolagents[all]) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4<5,>=4.9->markdownify>=0.14.1->smolagents[all]) (2.6)
# Requirement already satisfied: pycparser in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: colorama in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from click>=8.1.7->duckduckgo-search>=6.3.7->smolagents[all]) (0.4.6)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from e2b<2.0.0,>=1.0.4->e2b-code-interpreter>=1.0.3->smolagents[all]) (1.0.7)
# Requirement already satisfied: protobuf<6.0.0,>=3.20.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from e2b<2.0.0,>=1.0.4->e2b-code-interpreter>=1.0.3->smolagents[all]) (4.25.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from httpcore<2.0.0,>=1.0.5->e2b<2.0.0,>=1.0.4->e2b-code-interpreter>=1.0.3->smolagents[all]) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.55.10->smolagents[all]) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.55.10->smolagents[all]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.55.10->smolagents[all]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.55.10->smolagents[all]) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[all]) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.55.3->litellm>=1.55.10->smolagents[all]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.55.3->litellm>=1.55.10->smolagents[all]) (0.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.0->gradio>=5.8.0->smolagents[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.0->gradio>=5.8.0->smolagents[all]) (2.20.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio>=5.8.0->smolagents[all]) (1.5.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm>=1.55.10->smolagents[all]) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm>=1.55.10->smolagents[all]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm>=1.55.10->smolagents[all]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm>=1.55.10->smolagents[all]) (1.18.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ajaykumarkv\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->litellm>=1.55.10->smolagents[all]) (0.2.1)
# Downloading selenium-4.28.1-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 1.5 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.5 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.5 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.5 MB 1.2 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.5 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.5 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.5 MB 1.4 MB/s eta 0:00:06
#    ------------ --------------------------- 2.9/9.5 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 3.4/9.5 MB 1.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.9/9.5 MB 1.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.2/9.5 MB 1.6 MB/s eta 0:00:04
#    ------------------- -------------------- 4.7/9.5 MB 1.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.2/9.5 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.5/9.5 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 6.0/9.5 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 6.6/9.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.8/9.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.5 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 7.9/9.5 MB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 1.9 MB/s eta 0:00:00
# Downloading trio-0.28.0-py3-none-any.whl (486 kB)
# Using cached trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: helium
#   Building wheel for helium (pyproject.toml): started
#   Building wheel for helium (pyproject.toml): finished with status 'done'
#   Created wheel for helium: filename=helium-5.1.0-py3-none-any.whl size=30526 sha256=f5dbf1b425d508b433f2adff8edbb78a4d0ce04319252a4a638bf45ae8ef995d
#   Stored in directory: c:\users\ajaykumarkv\appdata\local\pip\cache\wheels\c5\11\72\052edae59a64302f68476e8127bc1a8687959fdab4628e65a8
# Successfully built helium
# Installing collected packages: sortedcontainers, wsproto, websocket-client, pysocks, outcome, trio, trio-websocket, selenium, helium
# Successfully installed helium-5.1.0 outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.28.1 sortedcontainers-2.4.0 trio-0.28.0 trio-websocket-0.11.1 websocket-client-1.8.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: smolagents 1.0.0 does not provide the extra 'all'
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from io import BytesIO
from time import sleep

import helium
from dotenv import load_dotenv
from PIL import Image
from selenium import webdriver
from selenium.common.exceptions import ElementNotInteractableException, TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

from smolagents import CodeAgent, LiteLLMModel, TransformersModel, tool
from smolagents.agents import ActionStep


load_dotenv()
import os

@tool
def search_item_ctrl_f(text: str, nth_result: int = 1) -> str:
    """
    Searches for text on the current page via Ctrl + F and jumps to the nth occurrence.
    Args:
        text: The text to search for
        nth_result: Which occurrence to jump to (default: 1, nullable)
    """
    elements = webdriver.find_elements(By.XPATH, f"//*[contains(text(), '{text}')]")
    if nth_result > len(elements):
        raise Exception(f"Match n°{nth_result} not found (only {len(elements)} matches found)")
    result = f"Found {len(elements)} matches for '{text}'."
    elem = elements[nth_result - 1]
    webdriver.execute_script("arguments[0].scrollIntoView(true);", elem)
    result += f"Focused on element {nth_result} of {len(elements)}"
    return result

@tool
def go_back() -> None:
    """Goes back to previous page."""
    driver.back()

@tool
def close_popups() -> str:
    """
    Closes any visible modal or pop-up on the page. Use this to dismiss pop-up windows! This does not work on cookie consent banners.
    """
    # Common selectors for modal close buttons and overlay elements
    modal_selectors = [
        "button[class*='close']",
        "[class*='modal']",
        "[class*='modal'] button",
        "[class*='CloseButton']",
        "[aria-label*='close']",
        ".modal-close",
        ".close-modal",
        ".modal .close",
        ".modal-backdrop",
        ".modal-overlay",
        "[class*='overlay']"
    ]

    wait = WebDriverWait(driver, timeout=0.5)

    for selector in modal_selectors:
        try:
            elements = wait.until(
                EC.presence_of_all_elements_located((By.CSS_SELECTOR, selector))
            )

            for element in elements:
                if element.is_displayed():
                    try:
                        # Try clicking with JavaScript as it's more reliable
                        driver.execute_script("arguments[0].click();", element)
                    except ElementNotInteractableException:
                        # If JavaScript click fails, try regular click
                        element.click()

        except TimeoutException:
            continue
        except Exception as e:
            print(f"Error handling selector {selector}: {str(e)}")
            continue
    return "Modals closed"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 20
#      17 load_dotenv()
#      18 import os
# ---> 20 @tool
#      21 def search_item_ctrl_f(text: str, nth_result: int = 1) -> str:
#      22     """
#      23     Searches for text on the current page via Ctrl + F and jumps to the nth occurrence.
#      24     Args:
#      25         text: The text to search for
#      26         nth_result: Which occurrence to jump to (default: 1, nullable)
#      27     """
#      28     elements = webdriver.find_elements(By.XPATH, f"//*[contains(text(), '{text}')]")
#
# File c:\Users\AjaykumarKV\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\tools.py:938, in tool(tool_function)
#     935         self.forward = function
#     936         self.is_initialized = True
# --> 938 simple_tool = SimpleTool(
#     939     parameters["name"],
#     940     parameters["description"],
#     941     parameters["parameters"]["properties"],
#     942     parameters["return"]["type"],
#     943     function=tool_function,
#     944 )
#     945 original_signature = inspect.signature(tool_function)
#     946 new_parameters = [
#     947     inspect.Parameter("self", inspect.Parameter.POSITIONAL_ONLY)
#     948 ] + list(original_signature.parameters.values())
#
# File c:\Users\AjaykumarKV\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\tools.py:107, in validate_after_init.<locals>.new_init(self, *args, **kwargs)
#     104 @wraps(original_init)
#     105 def new_init(self, *args, **kwargs):
#     106     original_init(self, *args, **kwargs)
# --> 107     self.validate_arguments()
#
# File c:\Users\AjaykumarKV\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\tools.py:229, in Tool.validate_arguments(self)
#     224     assert (
#     225         key in json_schema and "nullable" in json_schema[key]
#     226     ), f"Nullable argument '{key}' in inputs should have key 'nullable' set to True in function signature."
#     227 if key in json_schema and "nullable" in json_schema[key]:
#     228     assert (
# --> 229         "nullable" in value
#     230     ), f"Nullable argument '{key}' in function signature should have key 'nullable' set to True in inputs."
#
# AssertionError: Nullable argument 'nth_result' in function signature should have key 'nullable' set to True in inputs.
